# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df_2 = pd.read_csv('kickstarter.csv')
df_2 = pd.read_csv('kickstarter.csv')

df_2 = df_2[df_2['goal'] > 5]
df_2 = df_2[df_2['period'] < 80]
# Using 3 sigmas rule
n_sigmas = 3

std = df_2['created'].std()
mean = df_2['created'].mean()
df_2 = df_2[(df_2['created'] >= mean - std * n_sigmas) & (df_2['created'] <= mean + std * n_sigmas)]
print(mean - std * n_sigmas, mean + std * n_sigmas) # до 3

std = df_2['n_pled_t'].std()
mean = df_2['n_pled_t'].mean()
print(mean - std * n_sigmas, mean + std * n_sigmas) # до 28
df_2 = df_2[(df_2['n_pled_t'] >= mean - std * n_sigmas) & (df_2['n_pled_t'] <= mean + std * n_sigmas)]
# Out:
# -2.3196048878104314 2.8604102408992116
# -7.7375942406523315 27.854264975336246

# %%
#plt.hist(our_copy["period"], bins=25) 
#plt.ylabel('Количество проектов с таким period')
#plt.xlabel('Значения period')
#plt.show()
# после предобработки по goal, created, n_pled_t

# %%
our.shape
# Out:
# (8134, 38)

# %%
plt.hist(our["n_pled_t"], bins=8) 
plt.ylabel('Количество проектов с таким n_pled_t')
plt.xlabel('Значения n_pled_t')
plt.show()
# после предобработки по goal, created, n_pled_t, period

# %%
plt.hist(our["created"], bins=4) 
plt.ylabel('Количество проектов с таким created')
plt.xlabel('Значения created')
plt.show()
# после предобработки по goal, created, n_pled_t, period

# %%
plt.hist(our["text_am"], bins=6) 
plt.ylabel('Количество проектов с таким text_am')
plt.xlabel('Значения text_am')
plt.show()
# после предобработки по goal, created, n_pled_t, period

# %%
plt.hist(our["n_img"], bins=7) 
plt.ylabel('Количество проектов с таким n_img')
plt.xlabel('Значения n_img')
plt.show()
# после предобработки по goal, created, n_pled_t, period

# %%
plt.hist(our["n_vid"], bins=8) 
plt.ylabel('Количество проектов с таким n_vid')
plt.xlabel('Значения n_vid')
plt.show()
# после предобработки по goal, created, n_pled_t, period

# %%
plt.hist(our["cont"], bins=12) 
plt.ylabel('Количество проектов с таким cont')
plt.xlabel('Значения cont')
plt.show()
# после предобработки по goal, created, n_pled_t, period

# %%
plt.hist(our["mgp"], bins=8) 
plt.ylabel('Количество проектов с таким mgp')
plt.xlabel('Значения mgp')
plt.show()
# после предобработки по goal, created, n_pled_t, period
